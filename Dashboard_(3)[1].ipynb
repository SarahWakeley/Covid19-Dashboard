# %% [markdown]
# [DIY Covid-19 Dashboard Kit](https://github.com/fsmeraldi/diy-covid19dash) (C) Fabrizio Smeraldi, 2020 ([f.smeraldi@qmul.ac.uk](mailto:f.smeraldi@qmul.ac.uk) - [web](http://www.eecs.qmul.ac.uk/~fabri/)). All rights reserved.

# %% [markdown]
# # DIY Covid-19 Dashboard

# %% [markdown]
# Welcome to the Covid-19 Dashboard. This Dashboard has been built using the Public Health England API.

# %%
from IPython.display import clear_output
import ipywidgets as wdg
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
from uk_covid19 import Cov19API

# %%
# %matplotlib inline
# make figures larger
plt.rcParams['figure.dpi'] = 100

# %% [markdown]
# ## Load initial data from disk
#
# You should include "canned" data in ```.json``` files along with your dashboard. When the dashboard starts, it should load that data (the code below will be hidden when the dashboard is rendered by Voila).

# %%
#Loads JSON files and store the raw data in some variable.
with open("vaccineseries.json", "r") as INFILE:
    jsondata=json.load(INFILE)

# %%
jsondata
# Out:
# {'data': [{'date': '2022-11-24',
#    'cases': 20269112,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2022-11-23',
#    'cases': 20248860,
#    'reinfections': 1354499,
#    'vaccinations': 41991079},
#   {'date': '2022-11-22',
#    'cases': 20248860,
#    'reinfections': 1353814,
#    'vaccinations': 41990398},
#   {'date': '2022-11-21',
#    'cases': 20248860,
#    'reinfections': 1352664,
#    'vaccinations': 41989727},
#   {'date': '2022-11-20',
#    'cases': 20248860,
#    'reinfections': 1351366,
#    'vaccinations': 41989142},
#   {'date': '2022-11-19',
#    'cases': 20248860,
#    'reinfections': 1350438,
#    'vaccinations': 41988548},
#   {'date': '2022-11-18',
#    'cases': 20248860,
#    'reinfections': 1349722,
#    'vaccinations': 41986425},
#   {'date': '2022-11-17',
#    'cases': 20248860,
#    'reinfections': 1348907,
#    'vaccinations': 41985517},
#   {'date': '2022-11-16',
#    'cases': 20228010,
#    'reinfections': 1347924,
#    'vaccinations': 41984653},
#   {'date': '2022-11-15',
#    'cases': 20228010,
#    'reinfections': 1346902,
#    'vaccinations': 41983853},
#   {'date': '2022-11-14',
#    'cases': 20228010,
#    'reinfections': 1345765,
#    'vaccinations': 41983015},
#   {'date': '2022-11-13',
#    'cases': 20228010,
#    'reinfections': 1344479,
#    'vaccinations': 41982336},
#   {'date': '2022-11-12',
#    'cases': 20228010,
#    'reinfections': 1343521,
#    'vaccinations': 41981686},
#   {'date': '2022-11-11',
#    'cases': 20228010,
#    'reinfections': 1342824,
#    'vaccinations': 41979477},
#   {'date': '2022-11-10',
#    'cases': 20228010,
#    'reinfections': 1342000,
#    'vaccinations': 41978490},
#   {'date': '2022-11-09',
#    'cases': 20206637,
#    'reinfections': 1341083,
#    'vaccinations': 41977601},
#   {'date': '2022-11-08',
#    'cases': 20206637,
#    'reinfections': 1340011,
#    'vaccinations': 41976740},
#   {'date': '2022-11-07',
#    'cases': 20206637,
#    'reinfections': 1338819,
#    'vaccinations': 41975952},
#   {'date': '2022-11-06',
#    'cases': 20206637,
#    'reinfections': 1337438,
#    'vaccinations': 41975240},
#   {'date': '2022-11-05',
#    'cases': 20206637,
#    'reinfections': 1336388,
#    'vaccinations': 41974503},
#   {'date': '2022-11-04',
#    'cases': 20206637,
#    'reinfections': 1335614,
#    'vaccinations': 41972102},
#   {'date': '2022-11-03',
#    'cases': 20206637,
#    'reinfections': 1334784,
#    'vaccinations': 41971069},
#   {'date': '2022-11-02',
#    'cases': 20178456,
#    'reinfections': 1333725,
#    'vaccinations': 41970015},
#   {'date': '2022-11-01',
#    'cases': 20178456,
#    'reinfections': 1332544,
#    'vaccinations': 41969041},
#   {'date': '2022-10-31',
#    'cases': 20178456,
#    'reinfections': 1331173,
#    'vaccinations': 41968104},
#   {'date': '2022-10-30',
#    'cases': 20178456,
#    'reinfections': 1329649,
#    'vaccinations': 41967362},
#   {'date': '2022-10-29',
#    'cases': 20178456,
#    'reinfections': 1328391,
#    'vaccinations': 41966383},
#   {'date': '2022-10-28',
#    'cases': 20178456,
#    'reinfections': 1327430,
#    'vaccinations': 41963890},
#   {'date': '2022-10-27',
#    'cases': 20178456,
#    'reinfections': 1326349,
#    'vaccinations': 41962123},
#   {'date': '2022-10-26',
#    'cases': 20139321,
#    'reinfections': 1325107,
#    'vaccinations': 41960284},
#   {'date': '2022-10-25',
#    'cases': 20139321,
#    'reinfections': 1323647,
#    'vaccinations': 41958592},
#   {'date': '2022-10-24',
#    'cases': 20139321,
#    'reinfections': 1322128,
#    'vaccinations': 41957017},
#   {'date': '2022-10-23',
#    'cases': 20139321,
#    'reinfections': 1320285,
#    'vaccinations': 41955604},
#   {'date': '2022-10-22',
#    'cases': 20139321,
#    'reinfections': 1318874,
#    'vaccinations': 41954744},
#   {'date': '2022-10-21',
#    'cases': 20139321,
#    'reinfections': 1317663,
#    'vaccinations': 41952181},
#   {'date': '2022-10-20',
#    'cases': 20139321,
#    'reinfections': 1316072,
#    'vaccinations': 41950968},
#   {'date': '2022-10-19',
#    'cases': 20086702,
#    'reinfections': 1314301,
#    'vaccinations': 41949631},
#   {'date': '2022-10-18',
#    'cases': 20086702,
#    'reinfections': 1312302,
#    'vaccinations': 41948367},
#   {'date': '2022-10-17',
#    'cases': 20086702,
#    'reinfections': 1310070,
#    'vaccinations': 41947249},
#   {'date': '2022-10-16',
#    'cases': 20086702,
#    'reinfections': 1307378,
#    'vaccinations': 41946268},
#   {'date': '2022-10-15',
#    'cases': 20086702,
#    'reinfections': 1305342,
#    'vaccinations': 41945209},
#   {'date': '2022-10-14',
#    'cases': 20086702,
#    'reinfections': 1303771,
#    'vaccinations': 41942264},
#   {'date': '2022-10-13',
#    'cases': 20086702,
#    'reinfections': 1301924,
#    'vaccinations': 41940837},
#   {'date': '2022-10-12',
#    'cases': 20027667,
#    'reinfections': 1299848,
#    'vaccinations': 41939523},
#   {'date': '2022-10-11',
#    'cases': 20027667,
#    'reinfections': 1297531,
#    'vaccinations': 41938264},
#   {'date': '2022-10-10',
#    'cases': 20027667,
#    'reinfections': 1295177,
#    'vaccinations': 41937075},
#   {'date': '2022-10-09',
#    'cases': 20027667,
#    'reinfections': 1292432,
#    'vaccinations': 41935988},
#   {'date': '2022-10-08',
#    'cases': 20027667,
#    'reinfections': 1290302,
#    'vaccinations': 41934800},
#   {'date': '2022-10-07',
#    'cases': 20027667,
#    'reinfections': 1288686,
#    'vaccinations': 41931544},
#   {'date': '2022-10-06',
#    'cases': 20027667,
#    'reinfections': 1286565,
#    'vaccinations': 41930174},
#   {'date': '2022-10-05',
#    'cases': 19968866,
#    'reinfections': 1284363,
#    'vaccinations': 41928821},
#   {'date': '2022-10-04',
#    'cases': 19968866,
#    'reinfections': 1281865,
#    'vaccinations': 41927543},
#   {'date': '2022-10-03',
#    'cases': 19968866,
#    'reinfections': 1279183,
#    'vaccinations': 41926366},
#   {'date': '2022-10-02',
#    'cases': 19968866,
#    'reinfections': 1276276,
#    'vaccinations': 41925283},
#   {'date': '2022-10-01',
#    'cases': 19968866,
#    'reinfections': 1274161,
#    'vaccinations': 41924183},
#   {'date': '2022-09-30',
#    'cases': 19968866,
#    'reinfections': 1272634,
#    'vaccinations': 41921280},
#   {'date': '2022-09-29',
#    'cases': 19968866,
#    'reinfections': 1270991,
#    'vaccinations': 41919876},
#   {'date': '2022-09-28',
#    'cases': 19922057,
#    'reinfections': 1269201,
#    'vaccinations': 41918516},
#   {'date': '2022-09-27',
#    'cases': 19922057,
#    'reinfections': 1267271,
#    'vaccinations': 41917200},
#   {'date': '2022-09-26',
#    'cases': 19922057,
#    'reinfections': 1265281,
#    'vaccinations': 41916025},
#   {'date': '2022-09-25',
#    'cases': 19922057,
#    'reinfections': 1263116,
#    'vaccinations': 41914925},
#   {'date': '2022-09-24',
#    'cases': 19922057,
#    'reinfections': 1261340,
#    'vaccinations': 41913827},
#   {'date': '2022-09-23',
#    'cases': 19922057,
#    'reinfections': 1260037,
#    'vaccinations': 41911017},
#   {'date': '2022-09-22',
#    'cases': 19922057,
#    'reinfections': 1258559,
#    'vaccinations': 41909670},
#   {'date': '2022-09-21',
#    'cases': 19888584,
#    'reinfections': 1256903,
#    'vaccinations': 41908443},
#   {'date': '2022-09-20',
#    'cases': 19888584,
#    'reinfections': 1255054,
#    'vaccinations': 41907168},
#   {'date': '2022-09-19',
#    'cases': 19888584,
#    'reinfections': 1253019,
#    'vaccinations': 41905953},
#   {'date': '2022-09-18',
#    'cases': 19888584,
#    'reinfections': 1251339,
#    'vaccinations': 41905707},
#   {'date': '2022-09-17',
#    'cases': 19888584,
#    'reinfections': 1250283,
#    'vaccinations': 41904508},
#   {'date': '2022-09-16',
#    'cases': 19888584,
#    'reinfections': 1249483,
#    'vaccinations': 41901736},
#   {'date': '2022-09-15',
#    'cases': 19888584,
#    'reinfections': 1248520,
#    'vaccinations': 41900247},
#   {'date': '2022-09-14',
#    'cases': 19861556,
#    'reinfections': 1247346,
#    'vaccinations': 41898898},
#   {'date': '2022-09-13',
#    'cases': 19861556,
#    'reinfections': 1246141,
#    'vaccinations': 41897562},
#   {'date': '2022-09-12',
#    'cases': 19861556,
#    'reinfections': 1244962,
#    'vaccinations': 41896232},
#   {'date': '2022-09-11',
#    'cases': 19861556,
#    'reinfections': 1243613,
#    'vaccinations': 41894718},
#   {'date': '2022-09-10',
#    'cases': 19861556,
#    'reinfections': 1242572,
#    'vaccinations': 41894118},
#   {'date': '2022-09-09',
#    'cases': 19861556,
#    'reinfections': 1241831,
#    'vaccinations': 41892411},
#   {'date': '2022-09-08',
#    'cases': 19861556,
#    'reinfections': 1241056,
#    'vaccinations': 41891583},
#   {'date': '2022-09-07',
#    'cases': 19833314,
#    'reinfections': 1240176,
#    'vaccinations': 41890838},
#   {'date': '2022-09-06',
#    'cases': 19833314,
#    'reinfections': 1239166,
#    'vaccinations': 41890055},
#   {'date': '2022-09-05',
#    'cases': 19833314,
#    'reinfections': 1238095,
#    'vaccinations': 41889096},
#   {'date': '2022-09-04',
#    'cases': 19833314,
#    'reinfections': 1236862,
#    'vaccinations': 41888099},
#   {'date': '2022-09-03',
#    'cases': 19833314,
#    'reinfections': 1235873,
#    'vaccinations': 41887245},
#   {'date': '2022-09-02',
#    'cases': 19833314,
#    'reinfections': 1235115,
#    'vaccinations': 41885086},
#   {'date': '2022-09-01',
#    'cases': 19833314,
#    'reinfections': 1234313,
#    'vaccinations': 41883373},
#   {'date': '2022-08-31',
#    'cases': 19833314,
#    'reinfections': 1233285,
#    'vaccinations': 41881717},
#   {'date': '2022-08-30',
#    'cases': 19808426,
#    'reinfections': 1232247,
#    'vaccinations': 41879267},
#   {'date': '2022-08-29',
#    'cases': 19808426,
#    'reinfections': 1230935,
#    'vaccinations': 41876881},
#   {'date': '2022-08-28',
#    'cases': 19808426,
#    'reinfections': 1229839,
#    'vaccinations': 41876447},
#   {'date': '2022-08-27',
#    'cases': 19808426,
#    'reinfections': 1229150,
#    'vaccinations': 41875538},
#   {'date': '2022-08-26',
#    'cases': 19808426,
#    'reinfections': 1228527,
#    'vaccinations': 41872923},
#   {'date': '2022-08-25',
#    'cases': 19808426,
#    'reinfections': 1227822,
#    'vaccinations': 41870696},
#   {'date': '2022-08-24',
#    'cases': 19808426,
#    'reinfections': 1226966,
#    'vaccinations': 41868466},
#   {'date': '2022-08-23',
#    'cases': 19780734,
#    'reinfections': 1225962,
#    'vaccinations': 41866185},
#   {'date': '2022-08-22',
#    'cases': 19780734,
#    'reinfections': 1224951,
#    'vaccinations': 41863852},
#   {'date': '2022-08-21',
#    'cases': 19780734,
#    'reinfections': 1223769,
#    'vaccinations': 41861244},
#   {'date': '2022-08-20',
#    'cases': 19780734,
#    'reinfections': 1222839,
#    'vaccinations': 41860080},
#   {'date': '2022-08-19',
#    'cases': 19780734,
#    'reinfections': 1222178,
#    'vaccinations': 41856558},
#   {'date': '2022-08-18',
#    'cases': 19780734,
#    'reinfections': 1221349,
#    'vaccinations': 41854314},
#   {'date': '2022-08-17',
#    'cases': 19780734,
#    'reinfections': 1220363,
#    'vaccinations': 41851974},
#   {'date': '2022-08-16',
#    'cases': 19745612,
#    'reinfections': 1219246,
#    'vaccinations': 41849583},
#   {'date': '2022-08-15',
#    'cases': 19745612,
#    'reinfections': 1218025,
#    'vaccinations': 41847315},
#   {'date': '2022-08-14',
#    'cases': 19745612,
#    'reinfections': 1216603,
#    'vaccinations': 41845118},
#   {'date': '2022-08-13',
#    'cases': 19745612,
#    'reinfections': 1215444,
#    'vaccinations': 41843756},
#   {'date': '2022-08-12',
#    'cases': 19745612,
#    'reinfections': 1214521,
#    'vaccinations': 41840447},
#   {'date': '2022-08-11',
#    'cases': 19745612,
#    'reinfections': 1213397,
#    'vaccinations': 41838198},
#   {'date': '2022-08-10',
#    'cases': 19745612,
#    'reinfections': 1212035,
#    'vaccinations': 41835736},
#   {'date': '2022-08-09',
#    'cases': 19699384,
#    'reinfections': 1210544,
#    'vaccinations': 41833219},
#   {'date': '2022-08-08',
#    'cases': 19699384,
#    'reinfections': 1209008,
#    'vaccinations': 41830761},
#   {'date': '2022-08-07',
#    'cases': 19699384,
#    'reinfections': 1207092,
#    'vaccinations': 41827949},
#   {'date': '2022-08-06',
#    'cases': 19699384,
#    'reinfections': 1205686,
#    'vaccinations': 41826083},
#   {'date': '2022-08-05',
#    'cases': 19699384,
#    'reinfections': 1204595,
#    'vaccinations': 41821628},
#   {'date': '2022-08-04',
#    'cases': 19699384,
#    'reinfections': 1203226,
#    'vaccinations': 41818481},
#   {'date': '2022-08-03',
#    'cases': 19699384,
#    'reinfections': 1201678,
#    'vaccinations': 41815268},
#   {'date': '2022-08-02',
#    'cases': 19642180,
#    'reinfections': 1199986,
#    'vaccinations': 41811888},
#   {'date': '2022-08-01',
#    'cases': 19642180,
#    'reinfections': 1197996,
#    'vaccinations': 41808742},
#   {'date': '2022-07-31',
#    'cases': 19642180,
#    'reinfections': 1195831,
#    'vaccinations': 41805319},
#   {'date': '2022-07-30',
#    'cases': 19642180,
#    'reinfections': 1194049,
#    'vaccinations': 41802760},
#   {'date': '2022-07-29',
#    'cases': 19642180,
#    'reinfections': 1192582,
#    'vaccinations': 41796626},
#   {'date': '2022-07-28',
#    'cases': 19642180,
#    'reinfections': 1190849,
#    'vaccinations': 41792499},
#   {'date': '2022-07-27',
#    'cases': 19642180,
#    'reinfections': 1188860,
#    'vaccinations': 41787790},
#   {'date': '2022-07-26',
#    'cases': 19560297,
#    'reinfections': 1186616,
#    'vaccinations': 41783369},
#   {'date': '2022-07-25',
#    'cases': 19560297,
#    'reinfections': 1184187,
#    'vaccinations': 41778911},
#   {'date': '2022-07-24',
#    'cases': 19560297,
#    'reinfections': 1181398,
#    'vaccinations': 41774080},
#   {'date': '2022-07-23',
#    'cases': 19560297,
#    'reinfections': 1179023,
#    'vaccinations': 41770898},
#   {'date': '2022-07-22',
#    'cases': 19560297,
#    'reinfections': 1177091,
#    'vaccinations': 41762245},
#   {'date': '2022-07-21',
#    'cases': 19560297,
#    'reinfections': 1174571,
#    'vaccinations': 41756960},
#   {'date': '2022-07-20',
#    'cases': 19560297,
#    'reinfections': 1171652,
#    'vaccinations': 41752076},
#   {'date': '2022-07-19',
#    'cases': 19436864,
#    'reinfections': 1168409,
#    'vaccinations': 41747809},
#   {'date': '2022-07-18',
#    'cases': 19436864,
#    'reinfections': 1164891,
#    'vaccinations': 41744813},
#   {'date': '2022-07-17',
#    'cases': 19436864,
#    'reinfections': 1160769,
#    'vaccinations': 41741539},
#   {'date': '2022-07-16',
#    'cases': 19436864,
#    'reinfections': 1157137,
#    'vaccinations': 41737774},
#   {'date': '2022-07-15',
#    'cases': 19436864,
#    'reinfections': 1154141,
#    'vaccinations': 41726814},
#   {'date': '2022-07-14',
#    'cases': 19436864,
#    'reinfections': 1150357,
#    'vaccinations': 41721670},
#   {'date': '2022-07-13',
#    'cases': 19436864,
#    'reinfections': 1145769,
#    'vaccinations': 41716619},
#   {'date': '2022-07-12',
#    'cases': 19265078,
#    'reinfections': 1140773,
#    'vaccinations': 41711415},
#   {'date': '2022-07-11',
#    'cases': 19265078,
#    'reinfections': 1135002,
#    'vaccinations': 41706766},
#   {'date': '2022-07-10',
#    'cases': 19265078,
#    'reinfections': 1128423,
#    'vaccinations': 41702409},
#   {'date': '2022-07-09',
#    'cases': 19265078,
#    'reinfections': 1123185,
#    'vaccinations': 41698066},
#   {'date': '2022-07-08',
#    'cases': 19265078,
#    'reinfections': 1119100,
#    'vaccinations': 41686622},
#   {'date': '2022-07-07',
#    'cases': 19265078,
#    'reinfections': 1114431,
#    'vaccinations': 41681016},
#   {'date': '2022-07-06',
#    'cases': 19265078,
#    'reinfections': 1108982,
#    'vaccinations': 41675591},
#   {'date': '2022-07-05',
#    'cases': 19144946,
#    'reinfections': 1102891,
#    'vaccinations': 41670121},
#   {'date': '2022-07-04',
#    'cases': 19144946,
#    'reinfections': 1096557,
#    'vaccinations': 41664969},
#   {'date': '2022-07-03',
#    'cases': 19144946,
#    'reinfections': 1089507,
#    'vaccinations': 41659578},
#   {'date': '2022-07-02',
#    'cases': 19144946,
#    'reinfections': 1083811,
#    'vaccinations': 41654992},
#   {'date': '2022-07-01',
#    'cases': 19144946,
#    'reinfections': 1079771,
#    'vaccinations': 41643750},
#   {'date': '2022-06-30',
#    'cases': 19124226,
#    'reinfections': 1075456,
#    'vaccinations': 41638309},
#   {'date': '2022-06-29',
#    'cases': 19102513,
#    'reinfections': 1070780,
#    'vaccinations': 41633715},
#   {'date': '2022-06-28',
#    'cases': 19081094,
#    'reinfections': 1066117,
#    'vaccinations': 41629046},
#   {'date': '2022-06-27',
#    'cases': 19059682,
#    'reinfections': 1061608,
#    'vaccinations': 41624576},
#   {'date': '2022-06-26',
#    'cases': 19012379,
#    'reinfections': 1056989,
#    'vaccinations': 41620144},
#   {'date': '2022-06-25',
#    'cases': 19012379,
#    'reinfections': 1053361,
#    'vaccinations': 41616490},
#   {'date': '2022-06-24',
#    'cases': 19012379,
#    'reinfections': 1050729,
#    'vaccinations': 41606948},
#   {'date': '2022-06-23',
#    'cases': 18995906,
#    'reinfections': 1047782,
#    'vaccinations': 41602477},
#   {'date': '2022-06-22',
#    'cases': 18978435,
#    'reinfections': 1044579,
#    'vaccinations': 41598980},
#   {'date': '2022-06-21',
#    'cases': 18961236,
#    'reinfections': 1041276,
#    'vaccinations': 41595141},
#   {'date': '2022-06-20',
#    'cases': 18944806,
#    'reinfections': 1037939,
#    'vaccinations': 41591453},
#   {'date': '2022-06-19',
#    'cases': 18908381,
#    'reinfections': 1034632,
#    'vaccinations': 41587662},
#   {'date': '2022-06-18',
#    'cases': 18908381,
#    'reinfections': 1031965,
#    'vaccinations': 41584823},
#   {'date': '2022-06-17',
#    'cases': 18908381,
#    'reinfections': 1029982,
#    'vaccinations': 41576519},
#   {'date': '2022-06-16',
#    'cases': 18896327,
#    'reinfections': 1027973,
#    'vaccinations': 41572796},
#   {'date': '2022-06-15',
#    'cases': 18884257,
#    'reinfections': 1025713,
#    'vaccinations': 41569179},
#   {'date': '2022-06-14',
#    'cases': 18870862,
#    'reinfections': 1023431,
#    'vaccinations': 41565429},
#   {'date': '2022-06-13',
#    'cases': 18858834,
#    'reinfections': 1021180,
#    'vaccinations': 41561783},
#   {'date': '2022-06-12',
#    'cases': 18830603,
#    'reinfections': 1018694,
#    'vaccinations': 41558685},
#   {'date': '2022-06-11',
#    'cases': 18830603,
#    'reinfections': 1016814,
#    'vaccinations': 41555319},
#   {'date': '2022-06-10',
#    'cases': 18830603,
#    'reinfections': 1015389,
#    'vaccinations': 41545817},
#   {'date': '2022-06-09',
#    'cases': 18821397,
#    'reinfections': 1013874,
#    'vaccinations': 41541452},
#   {'date': '2022-06-08',
#    'cases': 18811661,
#    'reinfections': 1012187,
#    'vaccinations': 41537720},
#   {'date': '2022-06-07',
#    'cases': 18802365,
#    'reinfections': 1010418,
#    'vaccinations': 41533651},
#   {'date': '2022-06-06',
#    'cases': 18792128,
#    'reinfections': 1008747,
#    'vaccinations': 41529772},
#   {'date': '2022-06-05',
#    'cases': 18762989,
#    'reinfections': 1006997,
#    'vaccinations': 41526073},
#   {'date': '2022-06-04',
#    'cases': 18762989,
#    'reinfections': 1005588,
#    'vaccinations': 41523958},
#   {'date': '2022-06-03',
#    'cases': 18762989,
#    'reinfections': 1004668,
#    'vaccinations': 41518438},
#   {'date': '2022-06-02',
#    'cases': 18762989,
#    'reinfections': 1003877,
#    'vaccinations': 41517586},
#   {'date': '2022-06-01',
#    'cases': 18762989,
#    'reinfections': 1003130,
#    'vaccinations': 41516200},
#   {'date': '2022-05-31',
#    'cases': 18757683,
#    'reinfections': 1002373,
#    'vaccinations': 41508883},
#   {'date': '2022-05-30',
#    'cases': 18751882,
#    'reinfections': 1001543,
#    'vaccinations': 41501170},
#   {'date': '2022-05-29',
#    'cases': 18738306,
#    'reinfections': 1000656,
#    'vaccinations': 41494418},
#   {'date': '2022-05-28',
#    'cases': 18738306,
#    'reinfections': 999965,
#    'vaccinations': 41490627},
#   {'date': '2022-05-27',
#    'cases': 18738306,
#    'reinfections': 999373,
#    'vaccinations': 41480869},
#   {'date': '2022-05-26',
#    'cases': 18733650,
#    'reinfections': 998706,
#    'vaccinations': 41475850},
#   {'date': '2022-05-25',
#    'cases': 18728368,
#    'reinfections': 997888,
#    'vaccinations': 41471408},
#   {'date': '2022-05-24',
#    'cases': 18722566,
#    'reinfections': 997003,
#    'vaccinations': 41467235},
#   {'date': '2022-05-23',
#    'cases': 18716214,
#    'reinfections': 996058,
#    'vaccinations': 41463151},
#   {'date': '2022-05-22',
#    'cases': 18701642,
#    'reinfections': 994934,
#    'vaccinations': 41459458},
#   {'date': '2022-05-21',
#    'cases': 18701642,
#    'reinfections': 994128,
#    'vaccinations': 41456102},
#   {'date': '2022-05-20',
#    'cases': 18701642,
#    'reinfections': 993474,
#    'vaccinations': 41446394},
#   {'date': '2022-05-19',
#    'cases': 18695641,
#    'reinfections': 992665,
#    'vaccinations': 41440910},
#   {'date': '2022-05-18',
#    'cases': 18688946,
#    'reinfections': 991612,
#    'vaccinations': 41436057},
#   {'date': '2022-05-17',
#    'cases': 18681566,
#    'reinfections': 990537,
#    'vaccinations': 41430922},
#   {'date': '2022-05-16',
#    'cases': 18673471,
#    'reinfections': 989382,
#    'vaccinations': 41426015},
#   {'date': '2022-05-15',
#    'cases': 18656568,
#    'reinfections': 987952,
#    'vaccinations': 41421500},
#   {'date': '2022-05-14',
#    'cases': 18656568,
#    'reinfections': 986859,
#    'vaccinations': 41416987},
#   {'date': '2022-05-13',
#    'cases': 18656568,
#    'reinfections': 986032,
#    'vaccinations': 41405570},
#   {'date': '2022-05-12',
#    'cases': 18650062,
#    'reinfections': 985144,
#    'vaccinations': 41399405},
#   {'date': '2022-05-11',
#    'cases': 18639196,
#    'reinfections': 984110,
#    'vaccinations': 41393134},
#   {'date': '2022-05-10',
#    'cases': 18631175,
#    'reinfections': 982910,
#    'vaccinations': 41386436},
#   {'date': '2022-05-09',
#    'cases': 18621424,
#    'reinfections': 981530,
#    'vaccinations': 41379832},
#   {'date': '2022-05-08',
#    'cases': 18599739,
#    'reinfections': 979986,
#    'vaccinations': 41373579},
#   {'date': '2022-05-07',
#    'cases': 18599739,
#    'reinfections': 978739,
#    'vaccinations': 41367628},
#   {'date': '2022-05-06',
#    'cases': 18599739,
#    'reinfections': 977831,
#    'vaccinations': 41353773},
#   {'date': '2022-05-05',
#    'cases': 18590347,
#    'reinfections': 976687,
#    'vaccinations': 41345834},
#   {'date': '2022-05-04',
#    'cases': 18580049,
#    'reinfections': 975310,
#    'vaccinations': 41339070},
#   {'date': '2022-05-03',
#    'cases': 18565456,
#    'reinfections': 973769,
#    'vaccinations': 41331835},
#   {'date': '2022-05-02',
#    'cases': 18536477,
#    'reinfections': 971921,
#    'vaccinations': 41325446},
#   {'date': '2022-05-01',
#    'cases': 18536477,
#    'reinfections': 970322,
#    'vaccinations': 41323447},
#   {'date': '2022-04-30',
#    'cases': 18536477,
#    'reinfections': 969242,
#    'vaccinations': 41318400},
#   {'date': '2022-04-29',
#    'cases': 18536477,
#    'reinfections': 968323,
#    'vaccinations': 41304713},
#   {'date': '2022-04-28',
#    'cases': 18526781,
#    'reinfections': 967191,
#    'vaccinations': 41296638},
#   {'date': '2022-04-27',
#    'cases': 18515847,
#    'reinfections': 965855,
#    'vaccinations': 41289663},
#   {'date': '2022-04-26',
#    'cases': 18502386,
#    'reinfections': 964365,
#    'vaccinations': 41282458},
#   {'date': '2022-04-25',
#    'cases': 18489342,
#    'reinfections': 962706,
#    'vaccinations': 41276260},
#   {'date': '2022-04-24',
#    'cases': 18453469,
#    'reinfections': 960588,
#    'vaccinations': 41269624},
#   {'date': '2022-04-23',
#    'cases': 18453469,
#    'reinfections': 958969,
#    'vaccinations': 41262152},
#   {'date': '2022-04-22',
#    'cases': 18453469,
#    'reinfections': 957660,
#    'vaccinations': 41246680},
#   {'date': '2022-04-21',
#    'cases': 18437668,
#    'reinfections': 955988,
#    'vaccinations': 41236745},
#   {'date': '2022-04-20',
#    'cases': 18419203,
#    'reinfections': 954039,
#    'vaccinations': 41227743},
#   {'date': '2022-04-19',
#    'cases': 18398440,
#    'reinfections': 951838,
#    'vaccinations': 41218174},
#   {'date': '2022-04-18',
#    'cases': 18305250,
#    'reinfections': 949021,
#    'vaccinations': 41208530},
#   {'date': '2022-04-17',
#    'cases': 18305250,
#    'reinfections': 946329,
#    'vaccinations': 41205403},
#   {'date': '2022-04-16',
#    'cases': 18305250,
#    'reinfections': 944457,
#    'vaccinations': 41203399},
#   {'date': '2022-04-15',
#    'cases': 18305250,
#    'reinfections': 942728,
#    'vaccinations': 41192992},
#   {'date': '2022-04-14',
#    'cases': 18305250,
#    'reinfections': 940804,
#    'vaccinations': 41188489},
#   {'date': '2022-04-13',
#    'cases': 18277995,
#    'reinfections': 938344,
#    'vaccinations': 41177856},
#   {'date': '2022-04-12',
#    'cases': 18248680,
#    'reinfections': 935455,
#    'vaccinations': 41166711},
#   {'date': '2022-04-11',
#    'cases': 18217512,
#    'reinfections': 932251,
#    'vaccinations': 41156893},
#   {'date': '2022-04-10',
#    'cases': 18142371,
#    'reinfections': 928595,
#    'vaccinations': 41146720},
#   {'date': '2022-04-09',
#    'cases': 18142371,
#    'reinfections': 925824,
#    'vaccinations': 41139144},
#   {'date': '2022-04-08',
#    'cases': 18142371,
#    'reinfections': 923318,
#    'vaccinations': 41124073},
#   {'date': '2022-04-07',
#    'cases': 18108626,
#    'reinfections': 920235,
#    'vaccinations': 41114228},
#   {'date': '2022-04-06',
#    'cases': 18070000,
#    'reinfections': 916469,
#    'vaccinations': 41105639},
#   {'date': '2022-04-05',
#    'cases': 18027644,
#    'reinfections': 912180,
#    'vaccinations': 41096997},
#   {'date': '2022-04-04',
#    'cases': 17986241,
#    'reinfections': 907536,
#    'vaccinations': 41088633},
#   {'date': '2022-04-03',
#    'cases': 17864687,
#    'reinfections': 902204,
#    'vaccinations': 41079980},
#   {'date': '2022-04-02',
#    'cases': 17864687,
#    'reinfections': 898343,
#    'vaccinations': 41072413},
#   {'date': '2022-04-01',
#    'cases': 17864687,
#    'reinfections': 894995,
#    'vaccinations': 41057417},
#   {'date': '2022-03-31',
#    'cases': 17804704,
#    'reinfections': 890558,
#    'vaccinations': 41047731},
#   {'date': '2022-03-30',
#    'cases': 17742075,
#    'reinfections': 885386,
#    'vaccinations': 41036618},
#   {'date': '2022-03-29',
#    'cases': 17667861,
#    'reinfections': 877983,
#    'vaccinations': 41025490},
#   {'date': '2022-03-28',
#    'cases': 17603000,
#    'reinfections': 869921,
#    'vaccinations': 41015351},
#   {'date': '2022-03-27',
#    'cases': 17419944,
#    'reinfections': 860246,
#    'vaccinations': 41006032},
#   {'date': '2022-03-26',
#    'cases': 17419944,
#    'reinfections': 853595,
#    'vaccinations': 40999126},
#   {'date': '2022-03-25',
#    'cases': 17419944,
#    'reinfections': 848077,
#    'vaccinations': 40981358},
#   {'date': '2022-03-24',
#    'cases': 17356644,
#    'reinfections': 841370,
#    'vaccinations': 40969019},
#   {'date': '2022-03-23',
#    'cases': 17277446,
#    'reinfections': 833707,
#    'vaccinations': 40958494},
#   {'date': '2022-03-22',
#    'cases': 17191749,
#    'reinfections': 824954,
#    'vaccinations': 40946937},
#   {'date': '2022-03-21',
#    'cases': 17117061,
#    'reinfections': 815666,
#    'vaccinations': 40936590},
#   {'date': '2022-03-20',
#    'cases': 16928787,
#    'reinfections': 805118,
#    'vaccinations': 40925801},
#   {'date': '2022-03-19',
#    'cases': 16928787,
#    'reinfections': 797691,
#    'vaccinations': 40917156},
#   {'date': '2022-03-18',
#    'cases': 16928787,
#    'reinfections': 792062,
#    'vaccinations': 40899035},
#   {'date': '2022-03-17',
#    'cases': 16860551,
#    'reinfections': 785576,
#    'vaccinations': 40885400},
#   {'date': '2022-03-16',
#    'cases': 16785149,
#    'reinfections': 778361,
#    'vaccinations': 40872810},
#   {'date': '2022-03-15',
#    'cases': 16709007,
#    'reinfections': 770440,
#    'vaccinations': 40860129},
#   {'date': '2022-03-14',
#    'cases': 16644795,
#    'reinfections': 762607,
#    'vaccinations': 40847518},
#   {'date': '2022-03-13',
#    'cases': 16481364,
#    'reinfections': 754020,
#    'vaccinations': 40835998},
#   {'date': '2022-03-12',
#    'cases': 16481364,
#    'reinfections': 747736,
#    'vaccinations': 40826355},
#   {'date': '2022-03-11',
#    'cases': 16481364,
#    'reinfections': 742840,
#    'vaccinations': 40807645},
#   {'date': '2022-03-10',
#    'cases': 16425663,
#    'reinfections': 737634,
#    'vaccinations': 40794507},
#   {'date': '2022-03-09',
#    'cases': 16373115,
#    'reinfections': 732109,
#    'vaccinations': 40780943},
#   {'date': '2022-03-08',
#    'cases': 16321911,
#    'reinfections': 726492,
#    'vaccinations': 40768221},
#   {'date': '2022-03-07',
#    'cases': 16277054,
#    'reinfections': 721207,
#    'vaccinations': 40756182},
#   {'date': '2022-03-06',
#    'cases': 16182092,
#    'reinfections': 715773,
#    'vaccinations': 40745121},
#   {'date': '2022-03-05',
#    'cases': 16182092,
#    'reinfections': 712261,
#    'vaccinations': 40736946},
#   {'date': '2022-03-04',
#    'cases': 16182092,
#    'reinfections': 709664,
#    'vaccinations': 40719895},
#   {'date': '2022-03-03',
#    'cases': 16150464,
#    'reinfections': 706775,
#    'vaccinations': 40705555},
#   {'date': '2022-03-02',
#    'cases': 16117745,
#    'reinfections': 703732,
#    'vaccinations': 40691446},
#   {'date': '2022-03-01',
#    'cases': 16085841,
#    'reinfections': 700457,
#    'vaccinations': 40678830},
#   {'date': '2022-02-28',
#    'cases': 16059214,
#    'reinfections': 697581,
#    'vaccinations': 40665681},
#   {'date': '2022-02-27',
#    'cases': 15998983,
#    'reinfections': 694531,
#    'vaccinations': 40652793},
#   {'date': '2022-02-26',
#    'cases': 15998983,
#    'reinfections': 692500,
#    'vaccinations': 40643962},
#   {'date': '2022-02-25',
#    'cases': 15998983,
#    'reinfections': 691023,
#    'vaccinations': 40626147},
#   {'date': '2022-02-24',
#    'cases': 15975718,
#    'reinfections': 689257,
#    'vaccinations': 40612084},
#   {'date': '2022-02-23',
#    'cases': 15947871,
#    'reinfections': 687175,
#    'vaccinations': 40598687},
#   {'date': '2022-02-22',
#    'cases': 15918472,
#    'reinfections': 684785,
#    'vaccinations': 40583499},
#   {'date': '2022-02-21',
#    'cases': 15888557,
#    'reinfections': 682096,
#    'vaccinations': 40568416},
#   {'date': '2022-02-20',
#    'cases': 15859074,
#    'reinfections': 678976,
#    'vaccinations': 40555649},
#   {'date': '2022-02-19',
#    'cases': 15835403,
#    'reinfections': 676469,
#    'vaccinations': 40547323},
#   {'date': '2022-02-18',
#    'cases': 15803539,
#    'reinfections': 674196,
#    'vaccinations': 40529492},
#   {'date': '2022-02-17',
#    'cases': 15767071,
#    'reinfections': 671939,
#    'vaccinations': 40518037},
#   {'date': '2022-02-16',
#    'cases': 15727107,
#    'reinfections': 668729,
#    'vaccinations': 40498918},
#   {'date': '2022-02-15',
#    'cases': 15684719,
#    'reinfections': 665012,
#    'vaccinations': 40480043},
#   {'date': '2022-02-14',
#    'cases': 15648433,
#    'reinfections': 661206,
#    'vaccinations': 40462361},
#   {'date': '2022-02-13',
#    'cases': 15616753,
#    'reinfections': 657146,
#    'vaccinations': 40447180},
#   {'date': '2022-02-12',
#    'cases': 15584863,
#    'reinfections': 654162,
#    'vaccinations': 40436546},
#   {'date': '2022-02-11',
#    'cases': 15547597,
#    'reinfections': 651661,
#    'vaccinations': 40412996},
#   {'date': '2022-02-10',
#    'cases': 15501331,
#    'reinfections': 648443,
#    'vaccinations': 40388866},
#   {'date': '2022-02-09',
#    'cases': 15447906,
#    'reinfections': 644365,
#    'vaccinations': 40365399},
#   {'date': '2022-02-08',
#    'cases': 15389601,
#    'reinfections': 639312,
#    'vaccinations': 40342812},
#   {'date': '2022-02-07',
#    'cases': 15331148,
#    'reinfections': 633861,
#    'vaccinations': 40320631},
#   {'date': '2022-02-06',
#    'cases': 15282993,
#    'reinfections': 627487,
#    'vaccinations': 40299692},
#   {'date': '2022-02-05',
#    'cases': 15234229,
#    'reinfections': 622497,
#    'vaccinations': 40286577},
#   {'date': '2022-02-04',
#    'cases': 15177316,
#    'reinfections': 618569,
#    'vaccinations': 40261065},
#   {'date': '2022-02-03',
#    'cases': 15106124,
#    'reinfections': 613730,
#    'vaccinations': 40237872},
#   {'date': '2022-02-02',
#    'cases': 15028951,
#    'reinfections': 607437,
#    'vaccinations': 40213355},
#   {'date': '2022-02-01',
#    'cases': 14948735,
#    'reinfections': 600147,
#    'vaccinations': 40189651},
#   {'date': '2022-01-31',
#    'cases': 14845382,
#    'reinfections': 592133,
#    'vaccinations': 40165778},
#   {'date': '2022-01-30',
#    'cases': 14023177,
#    'reinfections': 583114,
#    'vaccinations': 40144989},
#   {'date': '2022-01-29',
#    'cases': 13963618,
#    'reinfections': 575722,
#    'vaccinations': 40122457},
#   {'date': '2022-01-28',
#    'cases': 13895065,
#    'reinfections': 569976,
#    'vaccinations': 40087662},
#   {'date': '2022-01-27',
#    'cases': 13817017,
#    'reinfections': 563158,
#    'vaccinations': 40057423},
#   {'date': '2022-01-26',
#    'cases': 13732435,
#    'reinfections': 555100,
#    'vaccinations': 40030906},
#   {'date': '2022-01-25',
#    'cases': 13642522,
#    'reinfections': 545883,
#    'vaccinations': 40003932},
#   {'date': '2022-01-24',
#    'cases': 13558510,
#    'reinfections': 536273,
#    'vaccinations': 39979967},
#   {'date': '2022-01-23',
#    'cases': 13482354,
#    'reinfections': 525318,
#    'vaccinations': 39955429},
#   {'date': '2022-01-22',
#    'cases': 13413441,
#    'reinfections': 516859,
#    'vaccinations': 39931440},
#   {'date': '2022-01-21',
#    'cases': 13341488,
#    'reinfections': 510566,
#    'vaccinations': 39892313},
#   {'date': '2022-01-20',
#    'cases': 13255586,
#    'reinfections': 503203,
#    'vaccinations': 39863428},
#   {'date': '2022-01-19',
#    'cases': 13160429,
#    'reinfections': 495146,
#    'vaccinations': 39836283},
#   {'date': '2022-01-18',
#    'cases': 13064494,
#    'reinfections': 485964,
#    'vaccinations': 39810924},
#   {'date': '2022-01-17',
#    'cases': 12979908,
#    'reinfections': 476145,
#    'vaccinations': 39786543},
#   {'date': '2022-01-16',
#    'cases': 12906041,
#    'reinfections': 465185,
#    'vaccinations': 39764835},
#   {'date': '2022-01-15',
#    'cases': 12840532,
#    'reinfections': 457281,
#    'vaccinations': 39741289},
#   {'date': '2022-01-14',
#    'cases': 12766944,
#    'reinfections': 451514,
#    'vaccinations': 39702307},
#   {'date': '2022-01-13',
#    'cases': 12680151,
#    'reinfections': 444787,
#    'vaccinations': 39677830},
#   {'date': '2022-01-12',
#    'cases': 12585787,
#    'reinfections': 436948,
#    'vaccinations': 39651309},
#   {'date': '2022-01-11',
#    'cases': 12469614,
#    'reinfections': 428386,
#    'vaccinations': 39625796},
#   {'date': '2022-01-10',
#    'cases': 12370121,
#    'reinfections': 418903,
#    'vaccinations': 39603501},
#   {'date': '2022-01-09',
#    'cases': 12254123,
#    'reinfections': 407842,
#    'vaccinations': 39582678},
#   {'date': '2022-01-08',
#    'cases': 12132895,
#    'reinfections': 400067,
#    'vaccinations': 39557141},
#   {'date': '2022-01-07',
#    'cases': 12008346,
#    'reinfections': 392565,
#    'vaccinations': 39515539},
#   {'date': '2022-01-06',
#    'cases': 11858941,
#    'reinfections': 382250,
#    'vaccinations': 39488592},
#   {'date': '2022-01-05',
#    'cases': 11706635,
#    'reinfections': 366340,
#    'vaccinations': 39462552},
#   {'date': '2022-01-04',
#    'cases': 11557285,
#    'reinfections': 347087,
#    'vaccinations': 39432943},
#   {'date': '2022-01-03',
#    'cases': 11408560,
#    'reinfections': 322803,
#    'vaccinations': 39400187},
#   {'date': '2022-01-02',
#    'cases': 11272332,
#    'reinfections': 302713,
#    'vaccinations': 39378320},
#   {'date': '2022-01-01',
#    'cases': 11151423,
#    'reinfections': 288063,
#    'vaccinations': 39362776},
#   {'date': '2021-12-31',
#    'cases': 10988851,
#    'reinfections': 279065,
#    'vaccinations': 39360275},
#   {'date': '2021-12-30',
#    'cases': 10828575,
#    'reinfections': 265106,
#    'vaccinations': 39342431},
#   {'date': '2021-12-29',
#    'cases': 10683026,
#    'reinfections': 247318,
#    'vaccinations': 39303858},
#   {'date': '2021-12-28',
#    'cases': 10545584,
#    'reinfections': 227718,
#    'vaccinations': 39265078},
#   {'date': '2021-12-27',
#    'cases': 10429274,
#    'reinfections': 212799,
#    'vaccinations': 39239153},
#   {'date': '2021-12-26',
#    'cases': 10332128,
#    'reinfections': 199795,
#    'vaccinations': 39220770},
#   {'date': '2021-12-25',
#    'cases': 10229538,
#    'reinfections': 192081,
#    'vaccinations': 39218943},
#   {'date': '2021-12-24',
#    'cases': 10115910,
#    'reinfections': 187731,
#    'vaccinations': 39218475},
#   {'date': '2021-12-23',
#    'cases': 10011650,
#    'reinfections': 178197,
#    'vaccinations': 39206818},
#   {'date': '2021-12-22',
#    'cases': 9905451,
#    'reinfections': 166621,
#    'vaccinations': 39170439},
#   {'date': '2021-12-21',
#    'cases': 9810446,
#    'reinfections': 154968,
#    'vaccinations': 39125695},
#   {'date': '2021-12-20',
#    'cases': 9731126,
#    'reinfections': 144390,
#    'vaccinations': 39079762},
#   {'date': '2021-12-19',
#    'cases': 9655061,
#    'reinfections': 135230,
#    'vaccinations': 39037397},
#   {'date': '2021-12-18',
#    'cases': 9584269,
#    'reinfections': 129446,
#    'vaccinations': 39001503},
#   {'date': '2021-12-17',
#    'cases': 9503176,
#    'reinfections': 123726,
#    'vaccinations': 38960351},
#   {'date': '2021-12-16',
#    'cases': 9420017,
#    'reinfections': 117408,
#    'vaccinations': 38924131},
#   {'date': '2021-12-15',
#    'cases': 9343520,
#    'reinfections': 110534,
#    'vaccinations': 38887307},
#   {'date': '2021-12-14',
#    'cases': 9275513,
#    'reinfections': 103474,
#    'vaccinations': 38853693},
#   {'date': '2021-12-13',
#    'cases': 9222932,
#    'reinfections': 97530,
#    'vaccinations': 38822841},
#   {'date': '2021-12-12',
#    'cases': 9178705,
#    'reinfections': 93532,
#    'vaccinations': 38797735},
#   {'date': '2021-12-11',
#    'cases': 9138773,
#    'reinfections': 91671,
#    'vaccinations': 38772324},
#   {'date': '2021-12-10',
#    'cases': 9092016,
#    'reinfections': 90248,
#    'vaccinations': 38736774},
#   {'date': '2021-12-09',
#    'cases': 9043108,
#    'reinfections': 88769,
#    'vaccinations': 38707508},
#   {'date': '2021-12-08',
#    'cases': 9000391,
#    'reinfections': 87200,
#    'vaccinations': 38676955},
#   {'date': '2021-12-07',
#    'cases': 8957091,
#    'reinfections': 85732,
#    'vaccinations': 38650816},
#   {'date': '2021-12-06',
#    'cases': 8918807,
#    'reinfections': 84490,
#    'vaccinations': 38627382},
#   {'date': '2021-12-05',
#    'cases': 8877883,
#    'reinfections': 83346,
#    'vaccinations': 38605799},
#   {'date': '2021-12-04',
#    'cases': 8841194,
#    'reinfections': 82764,
#    'vaccinations': 38583915},
#   {'date': '2021-12-03',
#    'cases': 8802632,
#    'reinfections': 82221,
#    'vaccinations': 38546998},
#   {'date': '2021-12-02',
#    'cases': 8758744,
#    'reinfections': 81623,
#    'vaccinations': 38519048},
#   {'date': '2021-12-01',
#    'cases': 8713738,
#    'reinfections': 80971,
#    'vaccinations': 38490773},
#   {'date': '2021-11-30',
#    'cases': 8673344,
#    'reinfections': 80270,
#    'vaccinations': 38460530},
#   {'date': '2021-11-29',
#    'cases': 8639754,
#    'reinfections': 79584,
#    'vaccinations': 38432043},
#   {'date': '2021-11-28',
#    'cases': 8605284,
#    'reinfections': 78836,
#    'vaccinations': 38407980},
#   {'date': '2021-11-27',
#    'cases': 8574315,
#    'reinfections': 78379,
#    'vaccinations': 38384006},
#   {'date': '2021-11-26',
#    'cases': 8538517,
#    'reinfections': 78000,
#    'vaccinations': 38349738},
#   {'date': '2021-11-25',
#    'cases': 8496990,
#    'reinfections': 77546,
#    'vaccinations': 38325732},
#   {'date': '2021-11-24',
#    'cases': 8457187,
#    'reinfections': 76991,
#    'vaccinations': 38303358},
#   {'date': '2021-11-23',
#    'cases': 8421911,
#    'reinfections': 76425,
#    'vaccinations': 38282242},
#   {'date': '2021-11-22',
#    'cases': 8385361,
#    'reinfections': 75893,
#    'vaccinations': 38262852},
#   {'date': '2021-11-21',
#    'cases': 8349363,
#    'reinfections': 75334,
#    'vaccinations': 38247377},
#   {'date': '2021-11-20',
#    'cases': 8316395,
#    'reinfections': 74931,
#    'vaccinations': 38235614},
#   {'date': '2021-11-19',
#    'cases': 8281117,
#    'reinfections': 74561,
#    'vaccinations': 38212220},
#   {'date': '2021-11-18',
#    'cases': 8244111,
#    'reinfections': 74149,
#    'vaccinations': 38193278},
#   {'date': '2021-11-17',
#    'cases': 8205448,
#    'reinfections': 73657,
#    'vaccinations': 38175822},
#   {'date': '2021-11-16',
#    'cases': 8175202,
#    'reinfections': 73171,
#    'vaccinations': 38156933},
#   {'date': '2021-11-15',
#    'cases': 8144766,
#    'reinfections': 72627,
#    'vaccinations': 38140374},
#   {'date': '2021-11-14',
#    'cases': 8113757,
#    'reinfections': 72041,
#    'vaccinations': 38125127},
#   {'date': '2021-11-13',
#    'cases': 8084740,
#    'reinfections': 71683,
#    'vaccinations': 38113245},
#   {'date': '2021-11-12',
#    'cases': 8051924,
#    'reinfections': 71367,
#    'vaccinations': 38089283},
#   {'date': '2021-11-11',
#    'cases': 8020241,
#    'reinfections': 70948,
#    'vaccinations': 38070294},
#   {'date': '2021-11-10',
#    'cases': 7984769,
#    'reinfections': 70482,
#    'vaccinations': 38050531},
#   {'date': '2021-11-09',
#    'cases': 7953228,
#    'reinfections': 70003,
#    'vaccinations': 38030059},
#   {'date': '2021-11-08',
#    'cases': 7925681,
#    'reinfections': 69528,
#    'vaccinations': 38012194},
#   {'date': '2021-11-07',
#    'cases': 7901039,
#    'reinfections': 68997,
#    'vaccinations': 37995016},
#   {'date': '2021-11-06',
#    'cases': 7877720,
#    'reinfections': 68657,
#    'vaccinations': 37983404},
#   {'date': '2021-11-05',
#    'cases': 7852005,
#    'reinfections': 68356,
#    'vaccinations': 37959289},
#   {'date': '2021-11-04',
#    'cases': 7823979,
#    'reinfections': 67990,
#    'vaccinations': 37940338},
#   {'date': '2021-11-03',
#    'cases': 7794507,
#    'reinfections': 67644,
#    'vaccinations': 37923439},
#   {'date': '2021-11-02',
#    'cases': 7760671,
#    'reinfections': 67262,
#    'vaccinations': 37905599},
#   {'date': '2021-11-01',
#    'cases': 7732441,
#    'reinfections': 66845,
#    'vaccinations': 37888967},
#   {'date': '2021-10-31',
#    'cases': 7700753,
#    'reinfections': 66297,
#    'vaccinations': 37873321},
#   {'date': '2021-10-30',
#    'cases': 7669614,
#    'reinfections': 65899,
#    'vaccinations': 37861236},
#   {'date': '2021-10-29',
#    'cases': 7633950,
#    'reinfections': 65608,
#    'vaccinations': 37837978},
#   {'date': '2021-10-28',
#    'cases': 7597473,
#    'reinfections': 65175,
#    'vaccinations': 37818768},
#   {'date': '2021-10-27',
#    'cases': 7564400,
#    'reinfections': 64745,
#    'vaccinations': 37799281},
#   {'date': '2021-10-26',
#    'cases': 7526898,
#    'reinfections': 64321,
#    'vaccinations': 37779172},
#   {'date': '2021-10-25',
#    'cases': 7494992,
#    'reinfections': 63906,
#    'vaccinations': 37760196},
#   {'date': '2021-10-24',
#    'cases': 7462144,
#    'reinfections': 63408,
#    'vaccinations': 37742390},
#   {'date': '2021-10-23',
#    'cases': 7430143,
#    'reinfections': 63064,
#    'vaccinations': 37728079},
#   {'date': '2021-10-22',
#    'cases': 7388884,
#    'reinfections': 62736,
#    'vaccinations': 37698598},
#   {'date': '2021-10-21',
#    'cases': 7347703,
#    'reinfections': 62317,
#    'vaccinations': 37676210},
#   {'date': '2021-10-20',
#    'cases': 7303864,
#    'reinfections': 61849,
#    'vaccinations': 37654708},
#   {'date': '2021-10-19',
#    'cases': 7262958,
#    'reinfections': 61368,
#    'vaccinations': 37632842},
#   {'date': '2021-10-18',
#    'cases': 7226658,
#    'reinfections': 60843,
#    'vaccinations': 37612115},
#   {'date': '2021-10-17',
#    'cases': 7187635,
#    'reinfections': 60240,
#    'vaccinations': 37592110},
#   {'date': '2021-10-16',
#    'cases': 7149533,
#    'reinfections': 59859,
#    'vaccinations': 37576643},
#   {'date': '2021-10-15',
#    'cases': 7110513,
#    'reinfections': 59521,
#    'vaccinations': 37545152},
#   {'date': '2021-10-14',
#    'cases': 7073467,
#    'reinfections': 59144,
#    'vaccinations': 37519343},
#   {'date': '2021-10-13',
#    'cases': 7035489,
#    'reinfections': 58663,
#    'vaccinations': 37496130},
#   {'date': '2021-10-12',
#    'cases': 7000356,
#    'reinfections': 58212,
#    'vaccinations': 37472673},
#   {'date': '2021-10-11',
#    'cases': 6967915,
#    'reinfections': 57715,
#    'vaccinations': 37450034},
#   {'date': '2021-10-10',
#    'cases': 6936327,
#    'reinfections': 57256,
#    'vaccinations': 37426966},
#   {'date': '2021-10-09',
#    'cases': 6906211,
#    'reinfections': 56917,
#    'vaccinations': 37409025},
#   {'date': '2021-10-08',
#    'cases': 6876192,
#    'reinfections': 56602,
#    'vaccinations': 37375792},
#   {'date': '2021-10-07',
#    'cases': 6845186,
#    'reinfections': 56249,
#    'vaccinations': 37349187},
#   {'date': '2021-10-06',
#    'cases': 6812848,
#    'reinfections': 55881,
#    'vaccinations': 37323403},
#   {'date': '2021-10-05',
#    'cases': 6780567,
#    'reinfections': 55510,
#    'vaccinations': 37297653},
#   {'date': '2021-10-04',
#    'cases': 6752536,
#    'reinfections': 55116,
#    'vaccinations': 37273226},
#   {'date': '2021-10-03',
#    'cases': 6725105,
#    'reinfections': 54726,
#    'vaccinations': 37249170},
#   {'date': '2021-10-02',
#    'cases': 6700702,
#    'reinfections': 54436,
#    'vaccinations': 37231280},
#   {'date': '2021-10-01',
#    'cases': 6674820,
#    'reinfections': 54218,
#    'vaccinations': 37198811},
#   {'date': '2021-09-30',
#    'cases': 6646963,
#    'reinfections': 53941,
#    'vaccinations': 37170295},
#   {'date': '2021-09-29',
#    'cases': 6617892,
#    'reinfections': 53636,
#    'vaccinations': 37139271},
#   {'date': '2021-09-28',
#    'cases': 6590514,
#    'reinfections': 53326,
#    'vaccinations': 37108452},
#   {'date': '2021-09-27',
#    'cases': 6561706,
#    'reinfections': 52964,
#    'vaccinations': 37078441},
#   {'date': '2021-09-26',
#    'cases': 6532847,
#    'reinfections': 52534,
#    'vaccinations': 37049628},
#   {'date': '2021-09-25',
#    'cases': 6507849,
#    'reinfections': 52197,
#    'vaccinations': 37027543},
#   {'date': '2021-09-24',
#    'cases': 6481363,
#    'reinfections': 51926,
#    'vaccinations': 36982400},
#   {'date': '2021-09-23',
#    'cases': 6453164,
#    'reinfections': 51598,
#    'vaccinations': 36942252},
#   {'date': '2021-09-22',
#    'cases': 6425056,
#    'reinfections': 51198,
#    'vaccinations': 36899509},
#   {'date': '2021-09-21',
#    'cases': 6398633,
#    'reinfections': 50844,
#    'vaccinations': 36859149},
#   {'date': '2021-09-20',
#    'cases': 6374123,
#    'reinfections': 50478,
#    'vaccinations': 36819671},
#   {'date': '2021-09-19',
#    'cases': 6347616,
#    'reinfections': 50071,
#    'vaccinations': 36778180},
#   {'date': '2021-09-18',
#    'cases': 6326046,
#    'reinfections': 49761,
#    'vaccinations': 36747014},
#   {'date': '2021-09-17',
#    'cases': 6303792,
#    'reinfections': 49507,
#    'vaccinations': 36679133},
#   {'date': '2021-09-16',
#    'cases': 6281236,
#    'reinfections': 49245,
#    'vaccinations': 36623189},
#   {'date': '2021-09-15',
#    'cases': 6258872,
#    'reinfections': 48966,
#    'vaccinations': 36563991},
#   {'date': '2021-09-14',
#    'cases': 6237505,
#    'reinfections': 48700,
#    'vaccinations': 36506966},
#   {'date': '2021-09-13',
#    'cases': 6218198,
#    'reinfections': 48403,
#    'vaccinations': 36450579},
#   {'date': '2021-09-12',
#    'cases': 6197654,
#    'reinfections': 48073,
#    'vaccinations': 36396210},
#   {'date': '2021-09-11',
#    'cases': 6178293,
#    'reinfections': 47837,
#    'vaccinations': 36352648},
#   {'date': '2021-09-10',
#    'cases': 6155149,
#    'reinfections': 47621,
#    'vaccinations': 36264333},
#   {'date': '2021-09-09',
#    'cases': 6129372,
#    'reinfections': 47326,
#    'vaccinations': 36184461},
#   {'date': '2021-09-08',
#    'cases': 6102850,
#    'reinfections': 47008,
#    'vaccinations': 36096755},
#   {'date': '2021-09-07',
#    'cases': 6074040,
#    'reinfections': 46619,
#    'vaccinations': 36020789},
#   {'date': '2021-09-06',
#    'cases': 6046799,
#    'reinfections': 46266,
#    'vaccinations': 35948983},
#   {'date': '2021-09-05',
#    'cases': 6019976,
#    'reinfections': 45816,
#    'vaccinations': 35878186},
#   {'date': '2021-09-04',
#    'cases': 5993444,
#    'reinfections': 45519,
#    'vaccinations': 35817887},
#   {'date': '2021-09-03',
#    'cases': 5964760,
#    'reinfections': 45250,
#    'vaccinations': 35699620},
#   {'date': '2021-09-02',
#    'cases': 5933034,
#    'reinfections': 44888,
#    'vaccinations': 35599976},
#   {'date': '2021-09-01',
#    'cases': 5904664,
#    'reinfections': 44481,
#    'vaccinations': 35496159},
#   {'date': '2021-08-31',
#    'cases': 5880134,
#    'reinfections': 44097,
#    'vaccinations': 35394426},
#   {'date': '2021-08-30',
#    'cases': 5859405,
#    'reinfections': 43654,
#    'vaccinations': 35289456},
#   {'date': '2021-08-29',
#    'cases': 5838323,
#    'reinfections': 43329,
#    'vaccinations': 35236830},
#   {'date': '2021-08-28',
#    'cases': 5816071,
#    'reinfections': 43086,
#    'vaccinations': 35170983},
#   {'date': '2021-08-27',
#    'cases': 5791272,
#    'reinfections': 42851,
#    'vaccinations': 35052303},
#   {'date': '2021-08-26',
#    'cases': 5764066,
#    'reinfections': 42552,
#    'vaccinations': 34935626},
#   {'date': '2021-08-25',
#    'cases': 5734967,
#    'reinfections': 42186,
#    'vaccinations': 34807201},
#   {'date': '2021-08-24',
#    'cases': 5707906,
#    'reinfections': 41830,
#    'vaccinations': 34678643},
#   {'date': '2021-08-23',
#    'cases': 5684645,
#    'reinfections': 41454,
#    'vaccinations': 34554369},
#   {'date': '2021-08-22',
#    'cases': 5660725,
#    'reinfections': 41069,
#    'vaccinations': 34441372},
#   {'date': '2021-08-21',
#    'cases': 5635046,
#    'reinfections': 40817,
#    'vaccinations': 34344551},
#   {'date': '2021-08-20',
#    'cases': 5608339,
#    'reinfections': 40555,
#    'vaccinations': 34167590},
# ...
#    'cases': 273314,
#    'reinfections': 362,
#    'vaccinations': None},
#   {'date': '2020-08-13',
#    'cases': 272030,
#    'reinfections': 343,
#    'vaccinations': None},
#   {'date': '2020-08-12',
#    'cases': 270971,
#    'reinfections': 337,
#    'vaccinations': None},
#   {'date': '2020-08-11',
#    'cases': 270046,
#    'reinfections': 318,
#    'vaccinations': None},
#   {'date': '2020-08-10',
#    'cases': 269011,
#    'reinfections': 292,
#    'vaccinations': None},
#   {'date': '2020-08-09',
#    'cases': 268312,
#    'reinfections': 278,
#    'vaccinations': None},
#   {'date': '2020-08-08',
#    'cases': 267324,
#    'reinfections': 274,
#    'vaccinations': None},
#   {'date': '2020-08-07',
#    'cases': 266645,
#    'reinfections': 268,
#    'vaccinations': None},
#   {'date': '2020-08-06',
#    'cases': 265849,
#    'reinfections': 257,
#    'vaccinations': None},
#   {'date': '2020-08-05',
#    'cases': 265023,
#    'reinfections': 243,
#    'vaccinations': None},
#   {'date': '2020-08-04',
#    'cases': 264219,
#    'reinfections': 221,
#    'vaccinations': None},
#   {'date': '2020-08-03',
#    'cases': 263602,
#    'reinfections': 194,
#    'vaccinations': None},
#   {'date': '2020-08-02',
#    'cases': 262746,
#    'reinfections': 178,
#    'vaccinations': None},
#   {'date': '2020-08-01',
#    'cases': 262070,
#    'reinfections': 174,
#    'vaccinations': None},
#   {'date': '2020-07-31',
#    'cases': 261348,
#    'reinfections': 169,
#    'vaccinations': None},
#   {'date': '2020-07-30',
#    'cases': 260534,
#    'reinfections': 160,
#    'vaccinations': None},
#   {'date': '2020-07-29',
#    'cases': 259722,
#    'reinfections': 145,
#    'vaccinations': None},
#   {'date': '2020-07-28',
#    'cases': 259022,
#    'reinfections': 130,
#    'vaccinations': None},
#   {'date': '2020-07-27',
#    'cases': 258475,
#    'reinfections': 117,
#    'vaccinations': None},
#   {'date': '2020-07-26',
#    'cases': 257859,
#    'reinfections': 107,
#    'vaccinations': None},
#   {'date': '2020-07-25',
#    'cases': 257138,
#    'reinfections': 106,
#    'vaccinations': None},
#   {'date': '2020-07-24',
#    'cases': 256428,
#    'reinfections': 103,
#    'vaccinations': None},
#   {'date': '2020-07-23',
#    'cases': 255740,
#    'reinfections': 95,
#    'vaccinations': None},
#   {'date': '2020-07-22',
#    'cases': 255038,
#    'reinfections': 90,
#    'vaccinations': None},
#   {'date': '2020-07-21',
#    'cases': 254519,
#    'reinfections': 82,
#    'vaccinations': None},
#   {'date': '2020-07-20',
#    'cases': 254120,
#    'reinfections': 76,
#    'vaccinations': None},
#   {'date': '2020-07-19',
#    'cases': 253585,
#    'reinfections': 66,
#    'vaccinations': None},
#   {'date': '2020-07-18',
#    'cases': 252913,
#    'reinfections': 61,
#    'vaccinations': None},
#   {'date': '2020-07-17',
#    'cases': 252117,
#    'reinfections': 59,
#    'vaccinations': None},
#   {'date': '2020-07-16',
#    'cases': 251482,
#    'reinfections': 58,
#    'vaccinations': None},
#   {'date': '2020-07-15',
#    'cases': 250885,
#    'reinfections': 53,
#    'vaccinations': None},
#   {'date': '2020-07-14',
#    'cases': 250379,
#    'reinfections': 49,
#    'vaccinations': None},
#   {'date': '2020-07-13',
#    'cases': 250007,
#    'reinfections': 45,
#    'vaccinations': None},
#   {'date': '2020-07-12',
#    'cases': 249510,
#    'reinfections': 45,
#    'vaccinations': None},
#   {'date': '2020-07-11',
#    'cases': 248895,
#    'reinfections': 45,
#    'vaccinations': None},
#   {'date': '2020-07-10',
#    'cases': 248089,
#    'reinfections': 41,
#    'vaccinations': None},
#   {'date': '2020-07-09',
#    'cases': 247609,
#    'reinfections': 38,
#    'vaccinations': None},
#   {'date': '2020-07-08',
#    'cases': 246992,
#    'reinfections': 32,
#    'vaccinations': None},
#   {'date': '2020-07-07',
#    'cases': 246386,
#    'reinfections': 26,
#    'vaccinations': None},
#   {'date': '2020-07-06',
#    'cases': 245814,
#    'reinfections': 23,
#    'vaccinations': None},
#   {'date': '2020-07-05',
#    'cases': 245483,
#    'reinfections': 19,
#    'vaccinations': None},
#   {'date': '2020-07-04',
#    'cases': 244991,
#    'reinfections': 18,
#    'vaccinations': None},
#   {'date': '2020-07-03',
#    'cases': 244412,
#    'reinfections': 18,
#    'vaccinations': None},
#   {'date': '2020-07-02',
#    'cases': 243910,
#    'reinfections': 17,
#    'vaccinations': None},
#   {'date': '2020-07-01',
#    'cases': 160764,
#    'reinfections': 13,
#    'vaccinations': None},
#   {'date': '2020-06-30',
#    'cases': 160587,
#    'reinfections': 10,
#    'vaccinations': None},
#   {'date': '2020-06-29',
#    'cases': 160391,
#    'reinfections': 9,
#    'vaccinations': None},
#   {'date': '2020-06-28',
#    'cases': 160292,
#    'reinfections': 7,
#    'vaccinations': None},
#   {'date': '2020-06-27',
#    'cases': 160150,
#    'reinfections': 6,
#    'vaccinations': None},
#   {'date': '2020-06-26',
#    'cases': 159958,
#    'reinfections': 4,
#    'vaccinations': None},
#   {'date': '2020-06-25',
#    'cases': 159696,
#    'reinfections': 3,
#    'vaccinations': None},
#   {'date': '2020-06-24',
#    'cases': 159435,
#    'reinfections': 3,
#    'vaccinations': None},
#   {'date': '2020-06-23',
#    'cases': 159328,
#    'reinfections': 2,
#    'vaccinations': None},
#   {'date': '2020-06-22',
#    'cases': 159118,
#    'reinfections': 1,
#    'vaccinations': None},
#   {'date': '2020-06-21',
#    'cases': 158940,
#    'reinfections': 1,
#    'vaccinations': None},
#   {'date': '2020-06-20',
#    'cases': 158725,
#    'reinfections': 1,
#    'vaccinations': None},
#   {'date': '2020-06-19',
#    'cases': 158401,
#    'reinfections': 1,
#    'vaccinations': None},
#   {'date': '2020-06-18',
#    'cases': 158078,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-06-17',
#    'cases': 157797,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-06-16',
#    'cases': 157545,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-06-15',
#    'cases': 157293,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-06-14',
#    'cases': 157074,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-06-13',
#    'cases': 156782,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-06-12',
#    'cases': 156410,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-06-11',
#    'cases': 156018,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-06-10',
#    'cases': 155714,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-06-09',
#    'cases': 155651,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-06-08',
#    'cases': 155000,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-06-07',
#    'cases': 154908,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-06-06',
#    'cases': 154680,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-06-05',
#    'cases': 154258,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-06-04',
#    'cases': 153807,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-06-03',
#    'cases': 153376,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-06-02',
#    'cases': 152914,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-06-01',
#    'cases': 152470,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-05-31',
#    'cases': 152176,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-05-30',
#    'cases': 151856,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-05-29',
#    'cases': 151982,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-05-28',
#    'cases': 151422,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-05-27',
#    'cases': 150903,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-05-26',
#    'cases': 150294,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-05-25',
#    'cases': 149802,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-05-24',
#    'cases': 149308,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-05-23',
#    'cases': 148724,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-05-22',
#    'cases': 147745,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-05-21',
#    'cases': 146662,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-05-20',
#    'cases': 145808,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-05-19',
#    'cases': 145376,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-05-18',
#    'cases': 144519,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-05-17',
#    'cases': 143703,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-05-16',
#    'cases': 142915,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-05-15',
#    'cases': 141779,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-05-14',
#    'cases': 140667,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-05-13',
#    'cases': 139478,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-05-12',
#    'cases': 138332,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-05-11',
#    'cases': 137265,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-05-10',
#    'cases': 136374,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-05-09',
#    'cases': 135367,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-05-08',
#    'cases': 134018,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-05-07',
#    'cases': 132324,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-05-06',
#    'cases': 130191,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-05-05',
#    'cases': 128580,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-05-04',
#    'cases': 126738,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-05-03',
#    'cases': 125253,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-05-02',
#    'cases': 123234,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-05-01',
#    'cases': 121006,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-04-30',
#    'cases': 118343,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-04-29',
#    'cases': 115859,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-04-28',
#    'cases': 114456,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-04-27',
#    'cases': 112467,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-04-26',
#    'cases': 110203,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-04-25',
#    'cases': 108051,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-04-24',
#    'cases': 105225,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-04-23',
#    'cases': 102221,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-04-22',
#    'cases': 99137,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-04-21',
#    'cases': 96117,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-04-20',
#    'cases': 93030,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-04-19',
#    'cases': 90629,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-04-18',
#    'cases': 87022,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-04-17',
#    'cases': 83474,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-04-16',
#    'cases': 79489,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-04-15',
#    'cases': 76371,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-04-14',
#    'cases': 73183,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-04-13',
#    'cases': 69329,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-04-12',
#    'cases': 66330,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-04-11',
#    'cases': 62658,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-04-10',
#    'cases': 58817,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-04-09',
#    'cases': 54554,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-04-08',
#    'cases': 50756,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-04-07',
#    'cases': 45968,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-04-06',
#    'cases': 42990,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-04-05',
#    'cases': 39814,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-04-04',
#    'cases': 34707,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-04-03',
#    'cases': 31797,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-04-02',
#    'cases': 28221,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-04-01',
#    'cases': 24638,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-03-31',
#    'cases': 21008,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-03-30',
#    'cases': 18594,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-03-29',
#    'cases': 16487,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-03-28',
#    'cases': 14427,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-03-27',
#    'cases': 12288,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-03-26',
#    'cases': 9782,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-03-25',
#    'cases': 7973,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-03-24',
#    'cases': 6843,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-03-23',
#    'cases': 5585,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-03-22',
#    'cases': 4792,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-03-21',
#    'cases': 4257,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-03-20',
#    'cases': 3384,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-03-19',
#    'cases': 2756,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-03-18',
#    'cases': 2182,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-03-17',
#    'cases': 1557,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-03-16',
#    'cases': 1196,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-03-15',
#    'cases': 1099,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-03-14',
#    'cases': 846,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-03-13',
#    'cases': 645,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-03-12',
#    'cases': 486,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-03-11',
#    'cases': 387,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-03-10',
#    'cases': 324,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-03-09',
#    'cases': 282,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-03-08',
#    'cases': 241,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-03-07',
#    'cases': 183,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-03-06',
#    'cases': 144,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-03-05',
#    'cases': 105,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-03-04',
#    'cases': 80,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-03-03',
#    'cases': 48,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-03-02',
#    'cases': 37,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-03-01',
#    'cases': 33,
#    'reinfections': None,
#    'vaccinations': None},
#   {'date': '2020-02-29',
#    'cases': 21,
#    'reinfections': None,
#    'vaccinations': None},
#   ...],
#  'lastUpdate': '2022-11-24T16:00:03.000000Z',
#  'length': 1029,
#  'totalPages': 1}

# %%
def parse_date(datestring):
    """ Convert a date string into a pandas datetime object """
    return pd.to_datetime(datestring, format="%Y-%m-%d") #creates a function to convert date string to pandas datetime object

def wrangle_data(rawdata):
    """ Parameters: rawdata - data from json file or API call. Returns a dataframe. """
    datalist=rawdata['data'] #retrieves list of dictionaries under the data key and assigns to datalist variable
    dates=[dictionary['date'] for dictionary in datalist ] #extracts all the dates from the dictionary and assigns to dates variable
    dates.sort() #sorts the date in 
    startdate=parse_date(dates[0]) #first item in the list
    enddate=parse_date(dates[-1]) #last item in the list
    index=pd.date_range(startdate, enddate, freq='D') #creates a date range, from the start to the end, with a frequency of each date being a day
    vaccinedf=pd.DataFrame(index=index, columns=['cases', 'reinfections', 'vaccinations']) #specifies its index and the title of the columns
    for entry in datalist: #each entry is a dictionary with date, cases, reinfections and vaccinations
        date=parse_date(entry['date']) #calls the parse_date function
        for column in ['cases', 'reinfections', 'vaccinations']: #list comprehension looping over each column
            #.isna checks the pd(parse_date) for missing values
            if pd.isna(vaccinedf.loc[date, column]): #.loc accesses a specific location in the dataframe (in this case, each loop)
                value= float(entry[column]) if entry[column]!=None else 0.0 #replaces None with 0
                vaccinedf.loc[date, column]=value #index,column in []
    vaccinedf.fillna(0.0, inplace=True) #if .isna returned True, fill in missing dates with 0.0
    return vaccinedf

vaccinedf=wrangle_data(jsondata) #df is the dataframe
vaccinedf
# Out:
#                  cases  reinfections  vaccinations
# 2020-01-31         2.0           0.0           0.0
# 2020-02-01         2.0           0.0           0.0
# 2020-02-02         2.0           0.0           0.0
# 2020-02-03         2.0           0.0           0.0
# 2020-02-04         2.0           0.0           0.0
# ...                ...           ...           ...
# 2022-11-20  20248860.0     1351366.0    41989142.0
# 2022-11-21  20248860.0     1352664.0    41989727.0
# 2022-11-22  20248860.0     1353814.0    41990398.0
# 2022-11-23  20248860.0     1354499.0    41991079.0
# 2022-11-24  20269112.0           0.0           0.0
#
# [1029 rows x 3 columns]

# %% [markdown]
# ## Download current data

# %% [markdown]
# Click the button below to refresh the data from Public Health England.

# %%
#here is a function which accesses the API for fresh data
def access_api():
    """ Accesses the PHE API. Returns raw data in the same format as data loaded from the "canned" JSON file. """
    filters = [
    "areaType=nation", #filters areaType by nation
    "areaName=England" #filters areaName by England
    ]
    structure = {
    "date": "date", 
    "cases": "cumCasesByPublishDate", 
    "reinfections": "cumReinfectionsBySpecimenDate", 
    "vaccinations": "cumPeopleVaccinatedCompleteByVaccinationDate",
    }
    api = Cov19API(filters=filters, structure=structure) #calls the Cov19API with filters and structure and assigns it to api variable
    vaccineseries=api.get_json() #creates a json file from the api
    return vaccineseries #return data read from the API

# %%
#function for the api button to access the api
def api_button_callback(button):
    """ Button callback - Accesses API, wrangles data, updates global variable df used for plotting. """
    apidata=access_api() #calls the access_api function to provide current data
    global vaccinedf
    vaccinedf=wrangle_data(apidata) #calls wrangle_data function and applies to the apidata which was previously called, and assigns to dataframe
    refresh_graph()
    apibutton.icon="check"

#the refresh data widget
apibutton=wdg.Button(
    description='Refresh data',
    disabled=False,
    button_style='info',
    tooltip='Click to download current Public Health England data',
    icon='download',
)

apibutton.on_click(api_button_callback) #when the button is clicked, calls the api to refresh the data

display(apibutton)
# Out:
# Button(button_style='info', description='Refresh data', icon='download', style=ButtonStyle(), tooltip='Click t…

# %% [markdown]
# ## Graphs and Analysis

# %% [markdown]
# The graph below compares the number of cases, reinfections and vaccinations in England.
#
# Please select a statistic. If you would like to select more than 1, please Ctrl-Click the statistics in the box.
#
# If you would like to change the scale of the graph, please choose between the toggle buttons.

# %%
#SelectMultiple widget
series=wdg.SelectMultiple(
    options=['cases', 'reinfections', 'vaccinations'],
    value=['cases', 'reinfections', 'vaccinations'],
    rows=3,
    description='Stats:',
    disabled=False,
)    

#ToggleButtons widget
scale=wdg.ToggleButtons(
    options=['Linear', 'Log'],
#    value='pineapple', # Defaults to 'pineapple'
#    layout={'width': 'max-
    description='Scale:',
    disabled=False,
    button_style='info',
    tooltips=['Linear scale', 'Log scale'],
)

#function to change the scale of the graph from log to linear
def vaccineseries_graph(gcols, gscale):
    if gscale=='Linear':
        logscale=False #if gscale=linear, turn off log
    else:
        logscale=True #else keep it on
    ncols=len(gcols)
    if ncols>0:
        vaccinedf[list(gcols)].plot(logy=logscale, linewidth=2, linestyle='dashed') #plots the graph
        plt.show()
    else:
        print("Please choose a stat") 
        print("(CTRL-Click to select more than one category)") #print these lines if user does not choose a statistic

# keep calling timeseries_graph(gcols=value_of_series, gscale=value_of_scale); 
# capture output in widget graph   

#function to refresh the graph
def refresh_graph():
    """ We change the value of the widget in order to force a redraw of the graph;
    this is useful when the data have been updated. """
    current=scale.value
    if current==scale.options[0]:
        other=scale.options[1]
    else:
        other=scale.options[0]
    scale.value=other # forces the redraw
    scale.value=current # now we can change it back
    
ctrls=wdg.VBox([series, scale]) #puts controls into a box
graph=wdg.interactive_output(vaccineseries_graph, {'gcols': series, 'gscale': scale}) #draws the graph and adds the interactive widgets
form=wdg.HBox([graph, ctrls]) #puts graph and controls in a box
display(form) #displays the graph and controls
# Out:
# HBox(children=(Output(), VBox(children=(SelectMultiple(description='Stats:', index=(0, 1, 2), options=('cases'…

# %% [markdown]
# **Author and Copyright Notice** 2022 Created by Sarah Wakeley, with code from Fabrizio Smeraldi (f.smeraldi@qmul.ac.uk - web), all rights reserved. Data source: *Based on UK Government [data](https://coronavirus.data.gov.uk/) published by [Public Health England](https://www.gov.uk/government/organisations/public-health-england).*
